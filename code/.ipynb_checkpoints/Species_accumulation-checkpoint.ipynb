# %% [markdown]
# ### Species accumulation through time

# %%
import pandas as pd
df = pd.read_csv('../data/type_localities_Bolivian_fishes.txt', sep='\t', encoding='latin-1')
print(df)
# Out:
#       nr.  year                 original_name  \
# 0     NaN  1846              Ovestias cuvieri
# 1    30.0  1846            Orestias humboldti
# 2    27.0  1846                Orestias albus
# 3    37.0  1846               Orestias luteus
# 4    40.0  1846           Orestias pentlandii
# ..    ...   ...                           ...
# 205  56.0  2022         Moema juanderibaensis
# 206  11.0  2023            Bujurquina mabelae
# 207  10.0  2023          Bujurquina beniensis
# 208  53.0  2023           Moema beltramonorum
# 209  84.0  2023  Bryconamericus parapetiensis
#
#                                         author name_category  \
# 0                            Valenciennes 1846         valid
# 1                            Valenciennes 1846       synonym
# 2                            Valenciennes 1846         valid
# 3                            Valenciennes 1846         valid
# 4                            Valenciennes 1846         valid
# ..                                         ...           ...
# 205                               Drawert 2022         valid
# 206  Careaga, Miranda & Carvajal-Vallejos 2023         valid
# 207  Careaga, Miranda & Carvajal-Vallejos 2023         valid
# 208                           Valdesalici 2023         valid
# 209      Román-Valencia, Ruiz-C & Taphorn 2023         valid
#
#                        valid_name country_type_locality  \
# 0                Orestias cuvieri         Lake Titicaca
# 1              Orestias humboldti         Lake Titicaca
# 2                   Orestias alba         Lake Titicaca
# 3                  Orestias lutea         Lake Titicaca
# 4             Orestias pentlandii         Lake Titicaca
# ..                            ...                   ...
# 205         Moema juanderibaensis               Bolivia
# 206            Bujurquina mabelae               Bolivia
# 207          Bujurquina beniensis               Bolivia
# 208           Moema beltramonorum               Bolivia
# 209  Bryconamericus parapetiensis               Bolivia
#
#      decimal_longitude_type_locality  decimal_latitude_type_locality  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
# ..                               ...                             ...
# 205                              NaN                             NaN
# 206                              NaN                             NaN
# 207                              NaN                             NaN
# 208                              NaN                             NaN
# 209                              NaN                             NaN
#
#                                 type_locality_verbatim  ...   latitude  \
# 0                                      Lac de Titicaca  ... -15.912056
# 1    Lacs de Titicaca, dans les environs de Guaichu...  ... -15.912056
# 2                            Riverains du lac Titicaca  ... -15.912056
# 3                                      Lac de Titicaca  ... -15.912056
# 4                                      Lac de Titicaca  ... -15.912056
# ..                                                 ...  ...        ...
# 205  Bolivia, Santa Cruz, municipality of Santa Ros...  ... -17.121556
# 206  Bolivia, Cochabamba Department, Chapare Provin...  ... -16.813256
# 207  Bolivia, La Paz Department, Sud Yungas Provinc...  ... -15.349703
# 208  Bolivia, Beni department, municipality of Bell...  ... -13.249167
# 209  Santa Cruz, Amazon, Iténez, Izozog/Parapeti, P...  ...        NaN
#
#      longitude                               datum uncertainty_(m)  \
# 0   -69.327967  (WGS84) World Geodetic System 1984         99154.0
# 1   -69.327967  (WGS84) World Geodetic System 1984         99154.0
# 2   -69.327967  (WGS84) World Geodetic System 1984         99154.0
# 3   -69.327967  (WGS84) World Geodetic System 1984         99154.0
# 4   -69.327967  (WGS84) World Geodetic System 1984         99154.0
# ..         ...                                 ...             ...
# 205 -63.556472                                 NaN             NaN
# 206 -65.359342                                 NaN             NaN
# 207 -67.177942                                 NaN             NaN
# 208 -63.696139                                 NaN             NaN
# 209        NaN                                 NaN             NaN
#
#         precision                 date          georeferenced_by  \
# 0    1.000000e-07  Pascal I. Hablützel  2024-01-28T16:57:29.035Z
# 1    1.000000e-07  Pascal I. Hablützel  2024-01-28T16:57:29.035Z
# 2    1.000000e-07  Pascal I. Hablützel  2024-01-28T16:57:29.035Z
# 3    1.000000e-07  Pascal I. Hablützel  2024-01-28T16:57:29.035Z
# 4    1.000000e-07  Pascal I. Hablützel  2024-01-28T16:57:29.035Z
# ..            ...                  ...                       ...
# 205           NaN                  NaN                       NaN
# 206           NaN                  NaN                       NaN
# 207           NaN                  NaN                       NaN
# 208           NaN                  NaN                       NaN
# 209           NaN                  NaN                       NaN
#
#                                        protocol               expedition notes
# 0    Georeferencing Quick Reference Guide. 2020  Joseph Barclay Pentland   NaN
# 1    Georeferencing Quick Reference Guide. 2020  Joseph Barclay Pentland   NaN
# 2    Georeferencing Quick Reference Guide. 2020  Joseph Barclay Pentland   NaN
# 3    Georeferencing Quick Reference Guide. 2020  Joseph Barclay Pentland   NaN
# 4    Georeferencing Quick Reference Guide. 2020  Joseph Barclay Pentland   NaN
# ..                                          ...                      ...   ...
# 205                                         NaN                      NaN   NaN
# 206                                         NaN                      NaN   NaN
# 207                                         NaN                      NaN   NaN
# 208                                         NaN                      NaN   NaN
# 209                                         NaN                      NaN   NaN
#
# [210 rows x 21 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/type_localities_Bolivian_fishes.txt', sep='\t', encoding='latin-1')

def count_occurrences(array):
  """Counts the occurrences of each number in an array and returns them as a list.

  Args:
      array: A list of elements.

  Returns:
      A list where the indices represent the unique elements and the values represent their counts.
  """
  counts = {}
  for num in array:
    if num in counts:
      counts[num] += 1
    else:
      counts[num] = 1
  return list(counts.values())  # Convert dictionary values to a list

# Example usage
array = df['year']
counts = count_occurrences(array)

print(counts)
# Calculate year-wise accumulation (optional, since data already has accumulated count)
cumulative_sum = []
total = 0

for num in counts:
  total += num
  cumulative_sum.append(total)

print(cumulative_sum)  # Output: [1, 3, 5, 8, 12, 16, 21]
print(list(set(df['year'])))
# Create the time series plot
plt.figure(figsize=(10, 6))
plt.plot(sorted(list(set(df['year']))), cumulative_sum, label='All names', color='black')

x_data = sorted(list(set(df['year'])))
last_x = x_data[-1]
last_y = cumulative_sum[-1]
text_x = last_x + 0.1
text_y = last_y + 2
latest_number_text = plt.text(text_x, text_y, str(cumulative_sum[-1]),
                              ha='center', va='baseline', fontsize=10)

# Add line with valid names
filtered_df = df[df['name_category'] == 'valid']
array = filtered_df['year']
counts = count_occurrences(array)

cumulative_sum = []
total = 0

for num in counts:
  total += num
  cumulative_sum.append(total)
    
plt.plot(sorted(list(set(filtered_df['year']))), cumulative_sum, label='Valid names', color='black', linestyle='--')

x_data = sorted(list(set(filtered_df['year'])))
last_x = x_data[-1]
last_y = cumulative_sum[-1]
text_x = last_x + 0.1
text_y = last_y + 2
latest_number_text = plt.text(text_x, text_y, str(cumulative_sum[-1]),
                              ha='center', va='baseline', fontsize=10)

# Add line with synonyms
filtered_df = df[df['name_category'] == 'synonym']
array = filtered_df['year']
counts = count_occurrences(array)

cumulative_sum = []
total = 0

for num in counts:
  total += num
  cumulative_sum.append(total)

plt.plot(sorted(list(set(filtered_df['year']))), cumulative_sum, label='Synonyms', color='black', linestyle=':')
x_data = sorted(list(set(filtered_df['year'])))
last_x = x_data[-1]
last_y = cumulative_sum[-1]
text_x = last_x + 0.1
text_y = last_y + 2
latest_number_text = plt.text(text_x, text_y, str(cumulative_sum[-1]),
                              ha='center', va='baseline', fontsize=10)
plt.xlabel('Year')
plt.ylabel('Accumulated number of names')
plt.title('Species descriptions over time')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [7, 1, 5, 1, 3, 1, 1, 1, 6, 6, 1, 6, 1, 3, 4, 5, 1, 1, 28, 1, 2, 3, 16, 1, 4, 6, 1, 1, 1, 1, 2, 1, 2, 1, 3, 1, 4, 3, 3, 3, 2, 1, 1, 2, 1, 2, 1, 3, 6, 2, 7, 1, 3, 3, 2, 1, 2, 3, 4, 3, 2, 4, 4, 2, 1, 1, 4]
# [7, 8, 13, 14, 17, 18, 19, 20, 26, 32, 33, 39, 40, 43, 47, 52, 53, 54, 82, 83, 85, 88, 104, 105, 109, 115, 116, 117, 118, 119, 121, 122, 124, 125, 128, 129, 133, 136, 139, 142, 144, 145, 146, 148, 149, 151, 152, 155, 161, 163, 170, 171, 174, 177, 179, 180, 182, 185, 189, 192, 194, 198, 202, 204, 205, 206, 210]
# [1923, 1924, 1925, 1927, 1929, 1940, 1942, 1943, 1944, 1966, 1968, 1969, 1972, 1973, 1846, 1975, 1976, 1978, 1981, 1854, 1855, 1982, 1983, 1858, 1984, 1985, 1987, 1988, 1989, 1990, 1991, 1996, 1997, 1999, 2001, 2002, 2003, 1876, 2004, 1878, 2005, 2006, 2007, 2008, 2009, 2010, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 1892, 2020, 2022, 2023, 1896, 1897, 1904, 1907, 1911, 1912, 1915, 1916, 1917, 1918]

# %% [markdown]
# ## Location of holotypes

# %%
import pandas as pd
df = pd.read_csv('../data/type_localities_Bolivian_fishes.txt', sep='\t', encoding='latin-1')
print(df)
# Out:
#       nr.    year                     original_name             author  \
# 0     NaN  1853.0                Acestra oxyrryncha          Kner 1853
# 1    15.0  1892.0  Crenicichla saxatilis semicincta  Steindachner 1892
# 2     2.0  1983.0          Apistogramma inconspicua     Kullander 1983
# 3    12.0  1987.0             Bujurquina oenolaemus     Kullander 1987
# 4    13.0  1983.0             Cichlasoma boliviense     Kullander 1983
# ..    ...     ...                               ...                ...
# 221   NaN     NaN                               NaN                NaN
# 222   NaN     NaN                               NaN                NaN
# 223   NaN     NaN                               NaN                NaN
# 224   NaN     NaN                               NaN                NaN
# 225   NaN     NaN                               NaN                NaN
#
#     name_category                valid_name collection_holotype  \
# 0           valid     Farlowella oxyrryncha           NMW 47797
# 1           valid      Saxatilia semicincta           NMW 33482
# 2           valid  Apistogramma inconspicua           IRSNB 637
# 3           valid     Bujurquina oenolaemus           IRSNB 666
# 4           valid     Cichlasoma boliviense           IRSNB 677
# ..            ...                       ...                 ...
# 221           NaN                       NaN                 NaN
# 222           NaN                       NaN                 NaN
# 223           NaN                       NaN                 NaN
# 224           NaN                       NaN                 NaN
# 225           NaN                       NaN                 NaN
#
#     country_holotype                                collection_paratype  \
# 0            Austria                                                 na
# 1            Austria                                   NMW 33483-84 (2)
# 2            Belgium  IRSNB 638 (orig. 2, now 1), MZUSP [ex IRSNB 63...
# 3            Belgium  IRSNB 667 (orig. 7, now 3 or 4), MZUSP [ex IRS...
# 4            Belgium  ANSP 84095 (1); BMNH 1927.10.4.57-60 (4); FMNH...
# ..               ...                                                ...
# 221              NaN                                                NaN
# 222              NaN                                                NaN
# 223              NaN                                                NaN
# 224              NaN                                                NaN
# 225              NaN                                                NaN
#
#                                       country_paratype  ...   latitude  \
# 0                                                   na  ... -10.599161
# 1                                              Austria  ... -17.028397
# 2                              Belgium, Brazil, Sweden  ... -16.052671
# 3                              Belgium, Brazil, Sweden  ... -18.452859
# 4    Belgium, Brazil, Germany, Sweden, United Kindo...  ... -16.369085
# ..                                                 ...  ...        ...
# 221                                                NaN  ...        NaN
# 222                                                NaN  ...        NaN
# 223                                                NaN  ...        NaN
# 224                                                NaN  ...        NaN
# 225                                                NaN  ...        NaN
#
#      longitude                               datum uncertainty_(m)  \
# 0   -65.410691  (WGS84) World Geodetic System 1984          2356.0
# 1   -65.433029  (WGS84) World Geodetic System 1984         16654.0
# 2   -61.143175  (WGS84) World Geodetic System 1984           277.0
# 3   -59.513097  (WGS84) World Geodetic System 1984          1175.0
# 4   -62.504817  (WGS84) World Geodetic System 1984          2165.0
# ..         ...                                 ...             ...
# 221        NaN                                 NaN             NaN
# 222        NaN                                 NaN             NaN
# 223        NaN                                 NaN             NaN
# 224        NaN                                 NaN             NaN
# 225        NaN                                 NaN             NaN
#
#         precision                 date  georeferenced_by  \
# 0    1.000000e-07  Pascal I. Hablützel    5/8/2024 19:09
# 1    1.000000e-07  Pascal I. Hablützel   1/28/2024 14:43
# 2    1.000000e-07  Pascal I. Hablützel   1/24/2024 18:01
# 3    1.000000e-07  Pascal I. Hablützel    1/26/2024 8:31
# 4    1.000000e-07  Pascal I. Hablützel    1/26/2024 8:32
# ..            ...                  ...               ...
# 221           NaN                  NaN               NaN
# 222           NaN                  NaN               NaN
# 223           NaN                  NaN               NaN
# 224           NaN                  NaN               NaN
# 225           NaN                  NaN               NaN
#
#                                        protocol       expedition  notes
# 0    Georeferencing Quick Reference Guide. 2020  Johann Natterer    NaN
# 1    Georeferencing Quick Reference Guide. 2020   Gustav Garlepp    NaN
# 2    Georeferencing Quick Reference Guide. 2020              NaN    NaN
# 3    Georeferencing Quick Reference Guide. 2020              NaN    NaN
# 4    Georeferencing Quick Reference Guide. 2020              NaN    NaN
# ..                                          ...              ...    ...
# 221                                         NaN              NaN    NaN
# 222                                         NaN              NaN    NaN
# 223                                         NaN              NaN    NaN
# 224                                         NaN              NaN    NaN
# 225                                         NaN              NaN    NaN
#
# [226 rows x 25 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count occurrences of each unique string (descending order)
string_counts = df['country_holotype'].value_counts().sort_values(ascending=True)

# Plot the bar chart (horizontal or vertical based on your preference)
# Option 1: Horizontal bar chart (most frequent on top)
string_counts.plot(kind='barh')

# Option 2: Vertical bar chart (most frequent on top)
# string_counts.plot(kind='bar')  # Uncomment for vertical bars

# Customize the plot (optional)
#plt.title("")
plt.xlabel("Count")
# plt.ylabel("country_holotype")  # Optional to remove y-axis label for horizontal plot
plt.xticks(rotation=0)  # Remove x-axis tick rotation (optional)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a new 'decade' column by grouping years by decades
df['decade'] = df['year'] // 10 * 10  # Floor division for decades

# Count occurrences per country within each decade
country_counts_per_decade = df.groupby(['decade', 'country_holotype'])['year'].count().unstack()

# Create the stacked bar plot with legend beside the plot
fig, ax = plt.subplots()  # Create a figure and axes object
country_counts_per_decade.plot(kind='bar', stacked=True, colormap='viridis', ax=ax)  # Adjust colormap as desired

# Customize legend placement
handles, labels = ax.get_legend_handles_labels()  # Get legend elements
ax.legend(handles, labels, title="Country", loc='center left', bbox_to_anchor=(1, 0.5))  # Adjust placement

# Customize the plot (optional)
plt.title("Count of Countries per Decade")
plt.xlabel("Decade")
plt.ylabel("Count")
plt.xticks(rotation=45)  # Optional: Rotate x-axis labels to avoid overlapping decades
plt.tight_layout()
plt.show()
